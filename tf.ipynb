# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("CLARIAH/wp6-missieven:latest", hoist=globals())
# A = use("CLARIAH/wp6-missieven", hoist=globals())
# Out:
# **Locating corpus resources ...**
# Status: latest release online <b>v1.1</b> is locally available
# <b title="latest release">app:</b> <span title="rv1.1=#e955ebf4ec1a294169d648790d921d684c859e81">~/text-fabric-data/github/CLARIAH/wp6-missieven/app</span>
# <b title="local release">data:</b> <span title="rv1.1=#e955ebf4ec1a294169d648790d921d684c859e81 offline under /Users/lodewijkpetram/text-fabric-data/github">~/text-fabric-data/github/CLARIAH/wp6-missieven/tf/1.0</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.14</a>, <a target="_blank" href="https://github.com/CLARIAH/wp6-missieven/blob/master/app" title="CLARIAH/wp6-missieven app">CLARIAH/wp6-missieven/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
v = A.nodeFromSectionStr("1")
lines = L.d(v, otype="line")

# %%
for line in lines:
    A.plain(line, fmt="layout-orig")
# Out:
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="http://resources.huygens.knaw.nl/retroboeken/generalemissiven/#page=26&amp;source=1" title="Show this document on Huygens" sec="1 3:1">1 3:1</a></span></span>  <span class="txtu">I. </span><span class="txtu">PIETER </span><span class="txtu">BOTH, </span><span class="txtu">AAN </span><span class="txtu">BOORD </span><span class="txtu">VAN </span><span class="txtu">HET </span><span class="txtu">WAPEN </span><span class="txtu">VAN </span><span class="txtu">AMSTERDAM, </span></div>
# ...
